# %% [markdown]
# Ref: https://github.com/openai/CLIP

# %% [markdown]
# # Visual Representation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### NOTE:
#  The review and some experiments I have done on CLIP to understand the use and power of CLIP model has been included in the fork version of the official here: https://github.com/babupallam/CLIP-Playground

# %% [markdown]
# ---
# ---
