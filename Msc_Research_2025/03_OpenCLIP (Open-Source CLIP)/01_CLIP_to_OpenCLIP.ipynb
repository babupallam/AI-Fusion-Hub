# %% [markdown]
# # **Comparison Between CLIP and OpenCLIP**

# %% [markdown]
# ## **1. CLIP (Contrastive Language-Image Pre-training by OpenAI)**
# **📌 Overview:**
# CLIP is a **multi-modal AI model developed by OpenAI** that understands **text and images** together. It is trained to **match images with their corresponding captions** using **contrastive learning**. CLIP performs **zero-shot classification**, meaning it does not need additional fine-tuning to classify new images into categories.

# %% [markdown]
# ### **🔹 Model Specifications**
# | Feature | CLIP (OpenAI) |
# |---------|--------------|
# | **Developer** | OpenAI |
# | **Release Year** | 2021 |
# | **Model Type** | Vision Transformer (ViT) / ResNet |
# | **Training Data** | Proprietary dataset (undisclosed) |
# | **Pretrained Models** | ViT-B/32, ViT-B/16, ViT-L/14, RN50, RN101, RN50x4, RN50x16, RN50x64 |
# | **Training Code** | ❌ Not available |
# | **Dataset Access** | ❌ Private dataset |
# | **Fine-Tuning Support** | ❌ Not directly available |
# | **Intended Use** | Research & Zero-shot classification |
#
# ### **🔹 Strengths**
# ✔️ **Zero-shot learning** (no additional training required for new tasks)
# ✔️ **Good generalization across multiple image datasets**
# ✔️ **Works on text-to-image & image-to-text tasks**
#
# ### **🔹 Limitations**
# ❌ **Dataset is private** (not open for retraining)
# ❌ **No official training code available**
# ❌ **Limited flexibility for custom applications**

# %% [markdown]
# ---

# %% [markdown]
# ## **2. OpenCLIP (Open-Source CLIP by LAION & Community)**
# **📌 Overview:**
# OpenCLIP is an **open-source implementation** of CLIP, developed by **LAION and other AI researchers**. Unlike OpenAI’s CLIP, OpenCLIP **uses publicly available datasets** like **LAION-400M, LAION-5B, and DataComp-1B** and allows researchers to **train from scratch or fine-tune models**.

# %% [markdown]
# ### **🔹 Model Specifications**
# | Feature | OpenCLIP (LAION) |
# |---------|--------------|
# | **Developer** | LAION & Community |
# | **Release Year** | 2022 |
# | **Model Type** | Vision Transformer (ViT) / ConvNeXt |
# | **Training Data** | Open datasets (LAION-400M, LAION-5B, DataComp-1B) |
# | **Pretrained Models** | ViT-B/32, ViT-B/16, ViT-L/14, ViT-G/14, ConvNext Models |
# | **Training Code** | ✅ Available |
# | **Dataset Access** | ✅ Open datasets available |
# | **Fine-Tuning Support** | ✅ Yes |
# | **Intended Use** | Research & Custom Model Training |
#
# ### **🔹 Strengths**
# ✔️ **Fully open-source** (training code + dataset)
# ✔️ **Supports training from scratch & fine-tuning**
# ✔️ **Multiple pre-trained models available**
# ✔️ **More flexible for research & experimentation**
#
# ### **🔹 Limitations**
# ❌ **Performance depends on dataset quality**
# ❌ **Requires compute resources for training**
# ❌ **May not match OpenAI’s CLIP in zero-shot tasks**

# %% [markdown]
# ---

# %% [markdown]
# ## **3. Key Differences: CLIP vs OpenCLIP**
# | Feature | CLIP (OpenAI) | OpenCLIP (LAION) |
# |---------|--------------|----------------|
# | **Dataset** | Private dataset | Public datasets (LAION-400M, LAION-5B) |
# | **Training Code** | ❌ Closed-source | ✅ Fully open-source |
# | **Pretrained Models** | Limited to OpenAI models | Many available models |
# | **Fine-Tuning** | ❌ Not supported | ✅ Fully supported |
# | **Customization** | ❌ Limited | ✅ High flexibility |
# | **Best Use Case** | Zero-shot classification | Research & custom training |

# %% [markdown]
# ---

# %% [markdown]
# ## **4. Which One Should You Use?**
# **✅ Use CLIP (OpenAI) if:**
# - You need **zero-shot image classification**.
# - You want a **pre-trained model** without further training.
# - You prefer **plug-and-play AI solutions**.
#
# **✅ Use OpenCLIP if:**
# - You need to **train or fine-tune** on **custom datasets**.
# - You require **full control** over training and hyperparameters.
# - You want **a fully open-source solution** with transparency.

# %% [markdown]
# ---

# %% [markdown]
# ## **CLIP vs OpenCLIP: Specification Differences**
#
# The table below highlights the key **technical differences** between **CLIP (OpenAI)** and **OpenCLIP (LAION)** in terms of architecture, training data, performance, and flexibility.
#
# ---
#
# ### **🔹 Specification Comparison Table**
# | Feature | **CLIP (OpenAI)** | **OpenCLIP (LAION)** |
# |---------|-----------------|---------------------|
# | **Developer** | OpenAI | LAION & Community |
# | **Release Year** | 2021 | 2022 |
# | **Model Type** | Vision Transformer (ViT) & ResNet | Vision Transformer (ViT) & ConvNeXt |
# | **Training Dataset** | Proprietary (undisclosed) | Public (LAION-400M, LAION-5B, DataComp-1B) |
# | **Pretrained Models Available** | ViT-B/32, ViT-B/16, ViT-L/14, RN50, RN101, RN50x4, RN50x16, RN50x64 | ViT-B/32, ViT-B/16, ViT-L/14, ViT-G/14, ConvNeXt Models |
# | **Model Resolution** | Up to 336px | Up to 378px |
# | **Training Code** | ❌ Not Available | ✅ Open-source & available |
# | **Fine-Tuning Support** | ❌ No | ✅ Yes |
# | **Zero-shot Learning Performance** | High | Comparable or better on some datasets |
# | **Inference Speed** | Optimized | Slightly slower due to flexibility |
# | **Dataset Access** | Private | Publicly available datasets |
# | **Custom Training** | ❌ Not possible | ✅ Fully supported |
# | **Best Use Case** | Zero-shot classification | Research, fine-tuning, and custom training |

# %% [markdown]
# ---

# %% [markdown]
# ## **🔹 Implementation Differences: CLIP vs OpenCLIP**
#
# Both **CLIP (OpenAI)** and **OpenCLIP (LAION)** follow a similar implementation pipeline but differ in terms of **loading models, training, and fine-tuning**. Below is a detailed comparison of how their implementation approaches vary.

# %% [markdown]
# ### **1️⃣ Model Loading & Initialization**
#
# | Feature | **CLIP (OpenAI)** | **OpenCLIP (LAION)** |
# |---------|-----------------|---------------------|
# | **Installation** | `pip install git+https://github.com/openai/CLIP.git` | `pip install open_clip_torch` |
# | **Import Model** | `import clip` | `import open_clip` |
# | **Load Model** | `clip.load("ViT-B/32", device=device)` | `open_clip.create_model_and_transforms("ViT-B-32", pretrained="laion2b_s34b_b79k")` |
# | **Tokenizer** | `clip.tokenize(["text prompt"])` | `open_clip.get_tokenizer("ViT-B-32")` |
# | **Image Preprocessing** | `preprocess(image)` | `preprocess(image)` |
# | **Text Encoding** | `model.encode_text(text_input)` | `model.encode_text(text_input)` |
# | **Image Encoding** | `model.encode_image(image_input)` | `model.encode_image(image_input)` |
#
# ✅ **Key Difference**: OpenCLIP requires an explicit **tokenizer retrieval (`open_clip.get_tokenizer`)**, whereas CLIP handles it internally.

# %% [markdown]
# ### **2️⃣ Performing Zero-Shot Classification**

# %% [markdown]
# #### **🔹 CLIP (OpenAI) Implementation**

# %%
# !pip install git+https://github.com/openai/CLIP.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 71.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 24.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.7 MB/s eta 0:00:00
# ...

# %%
import clip
import torch
from PIL import Image

# Load Model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# Prepare Image & Text
image = preprocess(Image.open("test.jpg")).unsqueeze(0).to(device)
text = clip.tokenize(["a cat", "a dog"]).to(device)

# Compute Features
with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    similarity = (image_features @ text_features.T).softmax(dim=-1)

print("Similarity:", similarity.cpu().numpy())
# Out:
# Similarity: [[7.9371594e-04 9.9920636e-01]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define text labels
labels = ["a cat", "a dog"]

# Convert similarity scores to numpy array
similarity_scores = similarity.cpu().numpy().flatten()

# Plot Image
plt.figure(figsize=(6, 6))
plt.imshow(Image.open("test.jpg"))
plt.axis("off")

# Display similarity scores
plt.title(f"Predictions:\n{labels[0]}: {similarity_scores[0]:.2f}, {labels[1]}: {similarity_scores[1]:.2f}")
plt.show()

# %% [markdown]
# #### **🔹 OpenCLIP (LAION) Implementation**

# %%
# !pip install open_clip_torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 52.5 MB/s eta 0:00:00
# ...

# %%
import open_clip
import torch
from PIL import Image

# Load Model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, _, preprocess = open_clip.create_model_and_transforms("ViT-B-32", pretrained="laion2b_s34b_b79k", device=device)

# Prepare Tokenizer
tokenizer = open_clip.get_tokenizer("ViT-B-32")

# Prepare Image & Text
image = preprocess(Image.open("test.jpg")).unsqueeze(0).to(device)
text = tokenizer(["a cat", "a dog"])

# Compute Features
with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    similarity = (100.0 * image_features @ text_features.T).softmax(dim=-1)

print("Similarity:", similarity.cpu().numpy())
# Out:
# Similarity: [[0. 1.]]

# %%
# ✅ Interpret Similarity Scores
labels = ["a cat", "a dog"]  # Corresponding text descriptions
similarity_scores = similarity.cpu().numpy()[0]  # Convert tensor to numpy array

# ✅ Print the Results
for label, score in zip(labels, similarity_scores):
    print(f"Similarity with '{label}': {score:.4f}")

# ✅ Identify the best match
best_match = labels[similarity_scores.argmax()]
print(f"\n🔹 Best Match: {best_match}")
# Out:
# Similarity with 'a cat': 0.0000
# Similarity with 'a dog': 1.0000
#
# 🔹 Best Match: a dog

# %%
import matplotlib.pyplot as plt

# ✅ Display Image with Prediction
plt.imshow(Image.open("test.jpg"))
plt.axis("off")  # Hide axis
plt.title(f"Predicted: {best_match}")  # Show best-matching label
plt.show()

# %% [markdown]
# ✅ **Key Difference**:
# - **OpenCLIP requires a separate tokenizer retrieval (`open_clip.get_tokenizer`)**, whereas CLIP internally manages it.
# - **Similarity computation differs** (CLIP directly applies `.softmax(dim=-1)`, whereas OpenCLIP **scales by 100.0 before applying `.softmax(dim=-1)`).**

# %% [markdown]
# ### **3️⃣ Fine-Tuning & Training Custom Models**
#
# | Feature | **CLIP (OpenAI)** | **OpenCLIP (LAION)** |
# |---------|-----------------|---------------------|
# | **Training Support** | ❌ Not Supported | ✅ Fully Supported |
# | **Custom Datasets** | ❌ Not Supported | ✅ Supported (via WebDataset, CSV, LAION, etc.) |
# | **Fine-Tuning** | ❌ No Fine-Tuning | ✅ Possible using `open_clip_train.main` |
# | **Zero-Shot Evaluation** | ✅ Pretrained Models Only | ✅ Supports training new models |
#
# #### **🔹 CLIP (OpenAI) Training**
# 🚫 **Not possible** – OpenAI has not released CLIP's training code.
#
# #### **🔹 OpenCLIP (LAION) Training**
# ✅ **Possible with `open_clip_train.main`**
# ```bash
# python -m open_clip_train.main \
#     --train-data "/path/to/train_data.csv" \
#     --val-data "/path/to/validation_data.csv"  \
#     --batch-size=128 \
#     --lr=1e-3 \
#     --epochs=30 \
#     --workers=8 \
#     --model ViT-B-32
# ```
#
# ✅ **Key Difference**:
# - OpenAI’s **CLIP is pre-trained and does not support fine-tuning**, whereas **OpenCLIP allows training from scratch or fine-tuning existing models.**
# - OpenCLIP **supports multiple data formats (WebDataset, CSV, LAION, etc.)** for training.

# %% [markdown]
# ### **4️⃣ Model Variants & Pretrained Weights**
#
# | Feature | **CLIP (OpenAI)** | **OpenCLIP (LAION)** |
# |---------|-----------------|---------------------|
# | **Pretrained Models** | ViT-B/32, ViT-B/16, ViT-L/14, RN50, RN101 | ViT-B/32, ViT-B/16, ViT-L/14, ViT-G/14, ConvNeXt Variants |
# | **Checkpoints Available** | ❌ No Official Checkpoints | ✅ Multiple Public Checkpoints |
# | **Custom Weights Loading** | ❌ Not Possible | ✅ Supports Hugging Face & Local Weights |
#
# ✅ **Key Difference**: OpenCLIP supports **loading and fine-tuning different pretrained weights**, whereas OpenAI’s CLIP is **limited to using fixed pre-trained models**.

# %% [markdown]
# ---

# %% [markdown]
# ## **🔹 Difference Between CLIP and OpenCLIP**
# Below is a structured comparison highlighting the key differences between **CLIP (by OpenAI)** and **OpenCLIP (an open-source alternative by LAION and the community).**
#
# ---
#
# ### **📌 1. Training Data**
# | Feature | CLIP (OpenAI) | OpenCLIP |
# |---------|--------------|----------|
# | **Training Data** | Uses proprietary, web-crawled datasets that are not publicly released. | Trained on **publicly available** datasets like **LAION-400M, LAION-2B, and DataComp-1B.** |
# | **Transparency** | Data sources are not disclosed. | Fully open-source and documented datasets. |
#
# ---
#
# ### **📌 2. Model Architectures**
# | Feature | CLIP (OpenAI) | OpenCLIP |
# |---------|--------------|----------|
# | **Backbone Architectures** | Uses ResNet and Vision Transformer (ViT) models like ViT-B/32 and ViT-L/14. | Supports **more diverse architectures** like ConvNext, ResNet, and **larger ViT models** (ViT-G/14, ViT-H/14). |
# | **Pretrained Variants** | Limited model releases (ViT-B/32, ViT-L/14). | Offers **more pretrained models** trained on different datasets and resolutions. |
#
# ---
#
# ### **📌 3. Availability & Access**
# | Feature | CLIP (OpenAI) | OpenCLIP |
# |---------|--------------|----------|
# | **Publicly Available?** | ❌ No, OpenAI did not release the full dataset or training code. | ✅ Yes, OpenCLIP is **fully open-source** and provides training code and datasets. |
# | **Fine-tuning Support?** | ❌ Not officially supported. | ✅ Designed for **fine-tuning** and training from scratch. |
#
# ---
#
# ### **📌 4. Performance & Usage**
# | Feature | CLIP (OpenAI) | OpenCLIP |
# |---------|--------------|----------|
# | **Zero-Shot Performance** | Well-optimized for zero-shot classification and retrieval. | Competitive performance with OpenAI’s CLIP, but with **greater flexibility** for training on **custom datasets.** |
# | **Benchmark Performance** | Consistent results across standard benchmarks. | Some OpenCLIP models **outperform OpenAI’s CLIP** on ImageNet Zero-Shot classification. |
#
# ---
#
# ### **📌 5. Implementation Differences**
# | Feature | CLIP (OpenAI) | OpenCLIP |
# |---------|--------------|----------|
# | **Installation** | `pip install git+https://github.com/openai/CLIP.git` | `pip install open_clip_torch` |
# | **Loading the Model** | `clip.load("ViT-B/32")` | `open_clip.create_model_and_transforms("ViT-B-32", pretrained="laion2b_s34b_b79k")` |
# | **Tokenization** | `clip.tokenize(text)` | `open_clip.get_tokenizer(model_name)(text)` |
#
# ---
#
# ### **📌 6. Use Cases & Community**
# | Feature | CLIP (OpenAI) | OpenCLIP |
# |---------|--------------|----------|
# | **Use Cases** | Primarily research and industry-level AI applications. | More suited for **custom training**, fine-tuning, and research in **open AI communities.** |
# | **Community & Support** | OpenAI’s internal team maintains it. | OpenCLIP is community-driven, allowing **faster updates and improvements.** |
#
# ---
#
# ### **📌 7. Ethical Considerations**
# | Feature | CLIP (OpenAI) | OpenCLIP |
# |---------|--------------|----------|
# | **Bias & Fairness** | Known biases but difficult to analyze due to lack of dataset access. | More transparency in dataset sources, but still subject to dataset biases. |
# | **Surveillance & Misuse** | Strictly against facial recognition and sensitive applications. | OpenCLIP is publicly available, but ethical use depends on the user. |
#
# ---
#
# ### **📌 8. Conclusion: Which One Should You Use?**
# | **Use Case** | **Recommended Option** |
# |-------------|----------------------|
# | Pretrained Zero-Shot Classification | **CLIP (OpenAI)** |
# | Custom Training / Fine-Tuning | **OpenCLIP** |
# | Academic Research with Open Datasets | **OpenCLIP** |
# | Industry Deployment & Commercial Use | **CLIP (OpenAI)** |
# | Running CLIP on Edge Devices (e.g., Raspberry Pi) | **OpenCLIP (lighter models available)** |
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# # **OpenCLIP is more flexible than CLIP because:**
#
# 1️⃣ **Open Source Training Data** – OpenCLIP is trained on publicly available datasets (like LAION-2B), while OpenAI’s CLIP was trained on a private dataset. This means **OpenCLIP can be extended and improved** by the community.
#
# 2️⃣ **More Model Choices** – OpenCLIP supports many architectures (ViT, ResNet, ConvNext, etc.), while CLIP mainly uses ViT-B/32 or ViT-L/14.
#
# 3️⃣ **Fine-Tuning Support** – OpenCLIP allows users to fine-tune models for **specific applications** (e.g., medical imaging, satellite imagery), while OpenAI’s CLIP is mostly used **as-is**.
#
# 4️⃣ **No API Restrictions** – OpenCLIP can be used freely without API limits, unlike OpenAI models that may have usage constraints.
